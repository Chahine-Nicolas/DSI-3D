# %%
TPmean =  1.34
TPmini =  0.04
TPmaxi = 2.99
TPstd =  0.73

FPmean =  364.29
FPmini =  59.99
FPmaxi = 745.29
FPstd =  199.6

Fnmean =  186.67
Fnmini =  0.17
Fnmaxi = 869.52
Fnstd =  280.77

Tnmean =  360.26
Tnmini =  5.45
Tnmaxi = 965.82
Tnstd =  156.02

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.scatter(FPmean,0, c='g')
plt.scatter(FPmaxi,0, c='b')
plt.scatter(FPmini,0, c='r')
plt.scatter(FPstd,0, c='black')

plt.scatter(Fnmean,1, c='g')
plt.scatter(Fnmaxi,1, c='b')
plt.scatter(Fnmini,1, c='r')
plt.scatter(Fnstd,1, c='black')

# %%
import matplotlib.pyplot as plt

x = [600, 1800, 2400, 2600, 2800, 3000, 3400]
hit = [53.8461, 88.46, 96.15, 96.15, 92.31, 92.31, 92.31]
hithard = [65.82, 93.71, 94.79, 95.28, 95.77, 94.28, 94.79]

plt.figure()
plt.plot(x, hit, label="hit score")
plt.plot(x, hithard, c='r', label="F1max")
plt.axhline(y = 92.31, color = 'g', linestyle = '-', label="last checkpoint hit score") 
plt.title("best checkpoint for sequence 06")
plt.xlabel("checkpoint")
plt.ylabel("Hitscore")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

x = [600, 1800, 2400, 2600, 2800, 3000, 3400]
hit = [53.8461, 88.46, 96.15, 96.15, 92.31, 92.31, 92.31]
hithard = [65.82, 93.71, 94.79, 95.28, 95.77, 94.28, 94.79]

plt.figure()
plt.plot(x, hit, label="with validation")
plt.axhline(y = 92.31, color = 'r', linestyle = '-', label="last checkpoint") 
plt.title("best checkpoint for sequence 06")
plt.xlabel("checkpoint")
plt.ylabel("Hitscore")
plt.show()

# %%
for i in range(0, 20):
    if i% 5 != 0:
        print(i)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9
# 11
# 12
# 13
# 14
# 16
# 17
# 18
# 19

# %%
plt.figure()

plt.scatter(TPmean,0, c='g', label='mean')
plt.scatter(TPmaxi,0, c='b', label='maxi')
plt.scatter(TPmini,0, c='r', label='mini')
plt.scatter(TPstd,0, c='black', label='std')

plt.scatter(Tnmean,1, c='g')
plt.scatter(Tnmaxi,1, c='b')
plt.scatter(Tnmini,1, c='r')
plt.scatter(Tnstd,1, c='black')

plt.scatter(FPmean,0, c='g')
plt.scatter(FPmaxi,0, c='b')
plt.scatter(FPmini,0, c='r')
plt.scatter(FPstd,0, c='black')

plt.scatter(Fnmean,0, c='g')
plt.scatter(Fnmaxi,0, c='b')
plt.scatter(Fnmini,0, c='r')
plt.scatter(Fnstd,0, c='black')

plt.xlabel("min_dist")
plt.legend()

# %%
import matplotlib.pyplot as plt
import numpy as np

# seq 00
TPmean =  0.0925
TPmini =  0.0004
TPmaxi = 0.2835
TPstd =  0.0719

FPmean =  0.2102
FPmini =  0.0292
FPmaxi = 0.2833
FPstd =  0.0549

Fnmean =  0.4925
Fnmini =  0.2859
Fnmaxi = 1.4221
Fnstd =  0.1946

Tnmean =  0.9521
Tnmini =  0.2864
Tnmaxi = 4.0565
Tnstd =  0.395


ax1 = plt.subplot(411)
ax1.scatter(TPmean,0, c='g', label='mean')
ax1.scatter(TPmaxi,0, c='b', label='maxi')
ax1.scatter(TPmini,0, c='r', label='mini')
ax1.scatter(TPstd,0, c='black', label='std')
ax1.title.set_text('TP')

ax2 = plt.subplot(412, sharex=ax1)
ax2.scatter(FPmean,0, c='g')
ax2.scatter(FPmaxi,0, c='b')
ax2.scatter(FPmini,0, c='r')
ax2.scatter(FPstd,0, c='black')
ax2.title.set_text('FP')

ax3 = plt.subplot(413)
ax3.scatter(Tnmean,0, c='g')
ax3.scatter(Tnmaxi,0, c='b')
ax3.scatter(Tnmini,0, c='r')
ax3.scatter(Tnstd,0, c='black')
ax3.title.set_text('TN')

ax4 = plt.subplot(414, sharex=ax3)
ax4.scatter(Fnmean,0, c='g')
ax4.scatter(Fnmaxi,0, c='b')
ax4.scatter(Fnmini,0, c='r')
ax4.scatter(Fnstd,0, c='black')
ax4.title.set_text('FN')
plt.subplots_adjust(top = 0.99, bottom=0.01, hspace=1.5, wspace=0.4)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# seq 02
TPmean =  0.0699
TPmini =  0.0005
TPmaxi = 0.2098
TPstd =  0.0539

FPmean =  0.1477
FPmini =  0.0387
FPmaxi = 0.21
FPstd =  0.051

Fnmean =  0.6572
Fnmini =  0.2116
Fnmaxi = 1.3561
Fnstd =  0.3132

Tnmean =  0.8796
Tnmini =  0.2148
Tnmaxi = 3.5776
Tnstd =  0.3756


ax1 = plt.subplot(411)
ax1.scatter(TPmean,0, c='g', label='mean')
ax1.scatter(TPmaxi,0, c='b', label='maxi')
ax1.scatter(TPmini,0, c='r', label='mini')
ax1.scatter(TPstd,0, c='black', label='std')
ax1.title.set_text('TP')

ax2 = plt.subplot(412, sharex=ax1)
ax2.scatter(FPmean,0, c='g')
ax2.scatter(FPmaxi,0, c='b')
ax2.scatter(FPmini,0, c='r')
ax2.scatter(FPstd,0, c='black')
ax2.title.set_text('FP')

ax3 = plt.subplot(413)
ax3.scatter(Tnmean,0, c='g')
ax3.scatter(Tnmaxi,0, c='b')
ax3.scatter(Tnmini,0, c='r')
ax3.scatter(Tnstd,0, c='black')
ax3.title.set_text('TN')

ax4 = plt.subplot(414, sharex=ax3)
ax4.scatter(Fnmean,0, c='g')
ax4.scatter(Fnmaxi,0, c='b')
ax4.scatter(Fnmini,0, c='r')
ax4.scatter(Fnstd,0, c='black')
ax4.title.set_text('FN')
plt.subplots_adjust(top = 0.99, bottom=0.01, hspace=1.5, wspace=0.4)
plt.title("min_dist ")
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
import numpy as np

# seq 05
TPmean =  0.1199
TPmini =  0.0016
TPmaxi = 0.3047
TPstd =  0.0748

FPmean =  0.2414
FPmini =  0.1008
FPmaxi = 0.3003
FPstd =  0.048

Fnmean =  0.56
Fnmini =  0.3060
Fnmaxi = 1.3419
Fnstd =  0.2263

Tnmean =  1.0132
Tnmini =  0.3080
Tnmaxi = 3.0328
Tnstd =  0.4224


ax1 = plt.subplot(411)
ax1.scatter(TPmean,0, c='g', label='mean')
ax1.scatter(TPmaxi,0, c='b', label='maxi')
ax1.scatter(TPmini,0, c='r', label='mini')
ax1.scatter(TPstd,0, c='black', label='std')
ax1.title.set_text('TP')

ax2 = plt.subplot(412, sharex=ax1)
ax2.scatter(FPmean,0, c='g')
ax2.scatter(FPmaxi,0, c='b')
ax2.scatter(FPmini,0, c='r')
ax2.scatter(FPstd,0, c='black')
ax2.title.set_text('FP')

ax3 = plt.subplot(413)
ax3.scatter(Tnmean,0, c='g')
ax3.scatter(Tnmaxi,0, c='b')
ax3.scatter(Tnmini,0, c='r')
ax3.scatter(Tnstd,0, c='black')
ax3.title.set_text('TN')

ax4 = plt.subplot(414, sharex=ax3)
ax4.scatter(Fnmean,0, c='g')
ax4.scatter(Fnmaxi,0, c='b')
ax4.scatter(Fnmini,0, c='r')
ax4.scatter(Fnstd,0, c='black')
ax4.title.set_text('FN')
plt.subplots_adjust(top = 0.99, bottom=0.01, hspace=1.5, wspace=0.4)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# seq 06
TPmean =  0.1065
TPmini =  0.004
TPmaxi = 0.3
TPstd =  0.0688

FPmean =  0.2036
FPmini =  0.0719
FPmaxi = 0.2943
FPstd =  0.0637

Fnmean =  0.4116
Fnmini =  0.3068
Fnmaxi = 0.6776
Fnstd =  0.1055

Tnmean =  1.0761
Tnmini =  0.3027
Tnmaxi = 2.9305
Tnstd =  0.523


ax1 = plt.subplot(411)
ax1.scatter(TPmean,0, c='g', label='mean')
ax1.scatter(TPmaxi,0, c='b', label='maxi')
ax1.scatter(TPmini,0, c='r', label='mini')
ax1.scatter(TPstd,0, c='black', label='std')
ax1.title.set_text('TP')

ax2 = plt.subplot(412, sharex=ax1)
ax2.scatter(FPmean,0, c='g')
ax2.scatter(FPmaxi,0, c='b')
ax2.scatter(FPmini,0, c='r')
ax2.scatter(FPstd,0, c='black')
ax2.title.set_text('FP')

ax3 = plt.subplot(413)
ax3.scatter(Tnmean,0, c='g')
ax3.scatter(Tnmaxi,0, c='b')
ax3.scatter(Tnmini,0, c='r')
ax3.scatter(Tnstd,0, c='black')
ax3.title.set_text('TN')

ax4 = plt.subplot(414, sharex=ax3)
ax4.scatter(Fnmean,0, c='g')
ax4.scatter(Fnmaxi,0, c='b')
ax4.scatter(Fnmini,0, c='r')
ax4.scatter(Fnstd,0, c='black')
ax4.title.set_text('FN')
plt.subplots_adjust(top = 0.99, bottom=0.01, hspace=1.5, wspace=0.4)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# seq 07
TPmean =  0.1490
TPmini =  0.0290
TPmaxi = 0.3042
TPstd =  0.0846

FPmean =  0.2458
FPmini =  0.1852
FPmaxi = 0.2966
FPstd =  0.0422

Fnmean =  0.4180
Fnmini =  0.3248
Fnmaxi = 0.5285
Fnstd =  0.0658

Tnmean =  1.0727
Tnmini =  0.3099
Tnmaxi = 5.5257
Tnstd =  0.5011


ax1 = plt.subplot(411)
ax1.scatter(TPmean,0, c='g', label='mean')
ax1.scatter(TPmaxi,0, c='b', label='maxi')
ax1.scatter(TPmini,0, c='r', label='mini')
ax1.scatter(TPstd,0, c='black', label='std')
ax1.title.set_text('TP')

ax2 = plt.subplot(412, sharex=ax1)
ax2.scatter(FPmean,0, c='g')
ax2.scatter(FPmaxi,0, c='b')
ax2.scatter(FPmini,0, c='r')
ax2.scatter(FPstd,0, c='black')
ax2.title.set_text('FP')

ax3 = plt.subplot(413)
ax3.scatter(Tnmean,0, c='g')
ax3.scatter(Tnmaxi,0, c='b')
ax3.scatter(Tnmini,0, c='r')
ax3.scatter(Tnstd,0, c='black')
ax3.title.set_text('TN')

ax4 = plt.subplot(414, sharex=ax3)
ax4.scatter(Fnmean,0, c='g')
ax4.scatter(Fnmaxi,0, c='b')
ax4.scatter(Fnmini,0, c='r')
ax4.scatter(Fnstd,0, c='black')
ax4.title.set_text('FN')
plt.subplots_adjust(top = 0.99, bottom=0.01, hspace=1.5, wspace=0.4)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# seq 08
TPmean =  0.1561
TPmini =  0.0055
TPmaxi = 0.2996
TPstd =  0.0740

FPmean =  0.6085
FPmini =  0.3056
FPmaxi = 1.5534
FPstd =  0.2464

Fnmean =  0.6085
Fnmini =  0.3056
Fnmaxi = 1.5534
Fnstd =  0.2464

Tnmean =  1.0684
Tnmini =  0.3007
Tnmaxi = 4.5389
Tnstd =  0.5241


ax1 = plt.subplot(411)
ax1.scatter(TPmean,0, c='g', label='mean')
ax1.scatter(TPmaxi,0, c='b', label='maxi')
ax1.scatter(TPmini,0, c='r', label='mini')
ax1.scatter(TPstd,0, c='black', label='std')
ax1.title.set_text('TP')

ax2 = plt.subplot(412, sharex=ax1)
ax2.scatter(FPmean,0, c='g')
ax2.scatter(FPmaxi,0, c='b')
ax2.scatter(FPmini,0, c='r')
ax2.scatter(FPstd,0, c='black')
ax2.title.set_text('FP')

ax3 = plt.subplot(413)
ax3.scatter(Tnmean,0, c='g')
ax3.scatter(Tnmaxi,0, c='b')
ax3.scatter(Tnmini,0, c='r')
ax3.scatter(Tnstd,0, c='black')
ax3.title.set_text('TN')

ax4 = plt.subplot(414, sharex=ax3)
ax4.scatter(Fnmean,0, c='g')
ax4.scatter(Fnmaxi,0, c='b')
ax4.scatter(Fnmini,0, c='r')
ax4.scatter(Fnstd,0, c='black')
ax4.title.set_text('FN')
plt.subplots_adjust(top = 0.99, bottom=0.01, hspace=1.5, wspace=0.4)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# seq 08
TPmean =  0.1561
TPmini =  0.0055
TPmaxi = 0.2996
TPstd =  0.0740

FPmean =  0.6085
FPmini =  0.3056
FPmaxi = 1.5534
FPstd =  0.2464

Fnmean =  0.6085
Fnmini =  0.3056
Fnmaxi = 1.5534
Fnstd =  0.2464

Tnmean =  1.0684
Tnmini =  0.3007
Tnmaxi = 4.5389
Tnstd =  0.5241


ax1 = plt.subplot(411)
ax1.scatter(TPmean,0, c='g', label='mean')
ax1.scatter(TPmaxi,0, c='b', label='maxi')
ax1.scatter(TPmini,0, c='r', label='mini')
ax1.scatter(TPstd,0, c='black', label='std')
ax1.title.set_text('TP')

ax2 = plt.subplot(412, sharex=ax1)
ax2.scatter(FPmean,0, c='g')
ax2.scatter(FPmaxi,0, c='b')
ax2.scatter(FPmini,0, c='r')
ax2.scatter(FPstd,0, c='black')
ax2.title.set_text('FP')

ax3 = plt.subplot(413)
ax3.scatter(Tnmean,0, c='g')
ax3.scatter(Tnmaxi,0, c='b')
ax3.scatter(Tnmini,0, c='r')
ax3.scatter(Tnstd,0, c='black')
ax3.title.set_text('TN')

ax4 = plt.subplot(414, sharex=ax3)
ax4.scatter(Fnmean,0, c='g')
ax4.scatter(Fnmaxi,0, c='b')
ax4.scatter(Fnmini,0, c='r')
ax4.scatter(Fnstd,0, c='black')
ax4.title.set_text('FN')
plt.subplots_adjust(top = 0.99, bottom=0.01, hspace=1.5, wspace=0.4)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters for the normal distribution
mean =  0.1561 # e.g., mean
std_dev = 0.0740  # e.g., standard deviation
x_min = 0.0055  # minimum value
x_max = 0.2996   # maximum value


# Generate x values
x = np.linspace(x_min, x_max, 500)

# Compute the PDF using scipy
y = norm.pdf(x, mean, std_dev)


# Parameters for the normal distribution
mean2 =  0.6085 # e.g., mean
std_dev2 = 0.2464  # e.g., standard deviation
x_min2 = 0.3056 # minimum value
x_max2 = 1.5534   # maximum value


# Generate x values
x2 = np.linspace(x_min2, x_max2, 500)

# Compute the PDF using scipy
y2 = norm.pdf(x, mean2, std_dev2)




# Plot the normal distribution
plt.plot(x, y, label=f'N({mean}, {std_dev}²)')
plt.plot(x2, y2, label=f'N({mean2}, {std_dev2}²)')
plt.title('Normal Distribution')
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.legend()
plt.axis('equal')
plt.grid()
plt.show()

# %%
import torch

# %%
state_dict = torch.load("/lustre/fswork/projects/rech/dki/ujo91el/checkpoints/git_gps_seq_08_80_20/checkpoint-5200/pytorch_model.bin")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 state_dict = torch.load("/lustre/fswork/projects/rech/dki/ujo91el/checkpoints/git_gps_seq_08_80_20/checkpoint-5200/pytorch_model.bin")
#
# File ~/.local/lib/python3.10/site-packages/torch/serialization.py:1026, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1024             except RuntimeError as e:
#    1025                 raise pickle.UnpicklingError(UNSAFE_MESSAGE + str(e)) from None
# -> 1026         return _load(opened_zipfile,
#    1027                      map_location,
#    1028                      pickle_module,
#    1029                      overall_storage=overall_storage,
#    1030                      **pickle_load_args)
#    1031 if mmap:
#    1032     raise RuntimeError("mmap can only be used with files saved with "
# ...
